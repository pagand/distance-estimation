# %% [markdown]
# # Setup
# Root directory is `./trackr-cnn-v2/`.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/CMPT\ 419\ 720\ Project/trackr-cnn-v2/
# !pip install pypng munkres
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/CMPT 419 720 Project/trackr-cnn-v2
# ...
#      |████████████████████████████████| 655kB 15.0MB/s
# ...
#   Created wheel for pypng: filename=pypng-0.0.20-cp37-none-any.whl size=67163 sha256=3915a7c6c9a960c35ac1b65e9d63eaf228d4519134fd5e8706ea04dab06be089
#   Stored in directory: /root/.cache/pip/wheels/41/6b/ef/0493b536b6d4722c2ae9486691b1d49b922b9877922beeabb3
# Successfully built pypng
# ...

# %% [markdown]
# # Forwarding and Tracking
# Refer to https://github.com/VisualComputingInstitute/TrackR-CNN
# ## Forwarding (Model Inferencing) with Pre-Trained Model
# Output is saved to `./trackr-cnn-v2/forwarded/conv3d_sep2/detections/`; specify the sequences to run with `video_tags_to_load`.

# %%
# !python main.py configs/conv3d_sep2 "{\"task\":\"forward_tracking\",\"dataset\":\"KITTI_segtrack_feed\",\"load_epoch_no\":5,\"batch_size\":5,\"export_detections\":true,\"do_tracking\":false,\"video_tags_to_load\":[\"0002\",\"0006\",\"0007\",\"0008\",\"0010\",\"0013\",\"0014\",\"0016\",\"0018\",\"0001\",\"0003\",\"0004\",\"0005\",\"0009\",\"0011\",\"0012\",\"0015\",\"0017\",\"0019\",\"0020\"]}"
# Out:
# 2021-04-19 03:52:53.339153: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Updating given config with dict OrderedDict([('task', 'forward_tracking'), ('dataset', 'KITTI_segtrack_feed'), ('load_epoch_no', 5), ('batch_size', 5), ('export_detections', True), ('do_tracking', False), ('video_tags_to_load', ['0002', '0006', '0007', '0008', '0010', '0013', '0014', '0016', '0018', '0001', '0003', '0004', '0005', '0009', '0011', '0012', '0015', '0017', '0019', '0020'])])
# {
#   # Engine settings
#   "model": "conv3d_sep2",
#   "task": "train_no_val",
#   "dataset": "KITTI_segtrack",
#   "log_verbosity": 5,
#   "gpus": 1,
#   #"own_dataset_per_gpu": true,
#   "use_summaries": false,
#   "write_summaries": false,
#   "collect_run_metadata": false,
#
#   # MaskRCNN on/off
#   "add_masks": true,
#
#   # Pretrained model from tensorpack
#   "load_init": "./models/converted",
# ...

# %% [markdown]
# ## Obtain Tracking Results
# Output is saved to `./trackr-cnn-v2/forwarded/conv3d_sep2/tracking_data/`; specify the sequences to run with `video_tags_to_load`.

# %%
# !python main.py configs/conv3d_sep2 "{\"build_networks\":false,\"import_detections\":true,\"task\":\"forward_tracking\",\"dataset\":\"KITTI_segtrack_feed\",\"do_tracking\":true,\"visualize_detections\":false,\"visualize_tracks\":false,\"load_epoch_no\":5,\"video_tags_to_load\":[\"0002\",\"0006\",\"0007\",\"0008\",\"0010\",\"0013\",\"0014\",\"0016\",\"0018\",\"0001\",\"0003\",\"0004\",\"0005\",\"0009\",\"0011\",\"0012\",\"0015\",\"0017\",\"0019\",\"0020\"]}"
# Out:
# 2021-04-19 06:17:44.889818: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Updating given config with dict OrderedDict([('build_networks', False), ('import_detections', True), ('task', 'forward_tracking'), ('dataset', 'KITTI_segtrack_feed'), ('do_tracking', True), ('visualize_detections', False), ('visualize_tracks', False), ('load_epoch_no', 5), ('video_tags_to_load', ['0002', '0006', '0007', '0008', '0010', '0013', '0014', '0016', '0018', '0001', '0003', '0004', '0005', '0009', '0011', '0012', '0015', '0017', '0019', '0020'])])
# {
#   # Engine settings
#   "model": "conv3d_sep2",
#   "task": "train_no_val",
#   "dataset": "KITTI_segtrack",
#   "log_verbosity": 5,
#   "gpus": 1,
#   #"own_dataset_per_gpu": true,
#   "use_summaries": false,
#   "write_summaries": false,
#   "collect_run_metadata": false,
#
#   # MaskRCNN on/off
#   "add_masks": true,
#
#   # Pretrained model from tensorpack
# ...
